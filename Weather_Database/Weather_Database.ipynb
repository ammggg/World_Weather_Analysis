# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime
import time
from scipy.stats import linregress

# %%
# API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city    
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count    
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard        
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shpykiv
# City not found. Skipping...
# Processing Record 2 of Set 1 | dongsheng
# Processing Record 3 of Set 1 | alpena
# Processing Record 4 of Set 1 | chengmai
# City not found. Skipping...
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | virginia beach
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | umm lajj
# Processing Record 13 of Set 1 | tuatapere
# Processing Record 14 of Set 1 | pampas
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | kastamonu
# Processing Record 18 of Set 1 | tuktoyaktuk
# Processing Record 19 of Set 1 | vostok
# Processing Record 20 of Set 1 | vila velha
# Processing Record 21 of Set 1 | arroyo
# Processing Record 22 of Set 1 | mogwase
# Processing Record 23 of Set 1 | te anau
# Processing Record 24 of Set 1 | alofi
# Processing Record 25 of Set 1 | kavieng
# Processing Record 26 of Set 1 | rezekne
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | dogondoutchi
# Processing Record 29 of Set 1 | assiniboia
# Processing Record 30 of Set 1 | ahipara
# Processing Record 31 of Set 1 | druzhba
# Processing Record 32 of Set 1 | vardo
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | kruisfontein
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | beloha
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | lichuan
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | raga
# Processing Record 42 of Set 1 | clyde river
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | mount gambier
# Processing Record 45 of Set 1 | krasnyy chikoy
# Processing Record 46 of Set 1 | bobonong
# City not found. Skipping...
# Processing Record 47 of Set 1 | zalantun
# Processing Record 48 of Set 1 | wadena
# Processing Record 49 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | mount isa
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | ishigaki
# Processing Record 9 of Set 2 | forbes
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | porto novo
# Processing Record 12 of Set 2 | lasa
# Processing Record 13 of Set 2 | algiers
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | khorixas
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | nemuro
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | asyut
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | huaicheng
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | shahrud
# Processing Record 24 of Set 2 | richards bay
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | cueto
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | aginskoye
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | beidao
# Processing Record 33 of Set 2 | essen
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | noyabrsk
# Processing Record 36 of Set 2 | ugoofaaru
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | mahajanga
# Processing Record 43 of Set 2 | ambon
# Processing Record 44 of Set 2 | wajid
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | beringovskiy
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | chicama
# Processing Record 1 of Set 3 | kayerkan
# Processing Record 2 of Set 3 | kozloduj
# City not found. Skipping...
# Processing Record 3 of Set 3 | hermanus
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | sioux lookout
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | iralaya
# Processing Record 9 of Set 3 | ous
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 3 | clearwater
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | namibe
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | nizhniy tsasuchey
# Processing Record 20 of Set 3 | narrabri
# Processing Record 21 of Set 3 | budisov nad budisovkou
# Processing Record 22 of Set 3 | kedrovyy
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | punta arenas
# Processing Record 32 of Set 3 | suileng
# Processing Record 33 of Set 3 | belaya gora
# Processing Record 34 of Set 3 | polis
# Processing Record 35 of Set 3 | eyl
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | kieta
# Processing Record 41 of Set 3 | mocuba
# Processing Record 42 of Set 3 | nolinsk
# Processing Record 43 of Set 3 | sarkand
# Processing Record 44 of Set 3 | itarema
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | amga
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | pisco
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | trincomalee
# Processing Record 1 of Set 4 | griffith
# Processing Record 2 of Set 4 | muhos
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | igarka
# Processing Record 5 of Set 4 | soe
# Processing Record 6 of Set 4 | tilichiki
# Processing Record 7 of Set 4 | roald
# Processing Record 8 of Set 4 | maniitsoq
# Processing Record 9 of Set 4 | nishihara
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | kutum
# Processing Record 13 of Set 4 | madiun
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 4 | baillif
# Processing Record 17 of Set 4 | turmalina
# Processing Record 18 of Set 4 | shingu
# Processing Record 19 of Set 4 | tarauaca
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | tautira
# Processing Record 22 of Set 4 | marsaxlokk
# Processing Record 23 of Set 4 | lonar
# Processing Record 24 of Set 4 | mackay
# Processing Record 25 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 4 | tiksi
# Processing Record 27 of Set 4 | tighnabruaich
# Processing Record 28 of Set 4 | ponta do sol
# Processing Record 29 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | montepuez
# Processing Record 35 of Set 4 | la peca
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | boyolangu
# Processing Record 38 of Set 4 | shaunavon
# Processing Record 39 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 4 | tsaratanana
# Processing Record 41 of Set 4 | zeya
# Processing Record 42 of Set 4 | palmer
# Processing Record 43 of Set 4 | mosalsk
# Processing Record 44 of Set 4 | ust-koksa
# Processing Record 45 of Set 4 | grindavik
# Processing Record 46 of Set 4 | klaksvik
# Processing Record 47 of Set 4 | marawi
# Processing Record 48 of Set 4 | dubbo
# Processing Record 49 of Set 4 | kikwit
# Processing Record 50 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 5 | urucara
# Processing Record 2 of Set 5 | kabelvag
# Processing Record 3 of Set 5 | matara
# Processing Record 4 of Set 5 | djambala
# Processing Record 5 of Set 5 | kumluca
# Processing Record 6 of Set 5 | alghero
# Processing Record 7 of Set 5 | yellowknife
# Processing Record 8 of Set 5 | fort morgan
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | dimayon
# Processing Record 11 of Set 5 | pemangkat
# Processing Record 12 of Set 5 | port-gentil
# Processing Record 13 of Set 5 | ancud
# Processing Record 14 of Set 5 | baker city
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | ayna
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | denkendorf
# Processing Record 19 of Set 5 | hanmer springs
# Processing Record 20 of Set 5 | logan
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | saint-augustin
# Processing Record 23 of Set 5 | apache junction
# Processing Record 24 of Set 5 | kuminskiy
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | poum
# Processing Record 27 of Set 5 | north bend
# Processing Record 28 of Set 5 | pangnirtung
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | ramhormoz
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | lander
# Processing Record 33 of Set 5 | salinopolis
# Processing Record 34 of Set 5 | grand gaube
# Processing Record 35 of Set 5 | upata
# Processing Record 36 of Set 5 | grande prairie
# Processing Record 37 of Set 5 | marzuq
# Processing Record 38 of Set 5 | portland
# Processing Record 39 of Set 5 | kahului
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | blackwater
# Processing Record 42 of Set 5 | hamilton
# Processing Record 43 of Set 5 | walvis bay
# Processing Record 44 of Set 5 | asfi
# Processing Record 45 of Set 5 | kholm
# Processing Record 46 of Set 5 | jiaohe
# Processing Record 47 of Set 5 | acapulco
# Processing Record 48 of Set 5 | berdigestyakh
# Processing Record 49 of Set 5 | victor harbor
# Processing Record 50 of Set 5 | chabahar
# Processing Record 1 of Set 6 | dole
# Processing Record 2 of Set 6 | jardim
# Processing Record 3 of Set 6 | ilulissat
# Processing Record 4 of Set 6 | liwale
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | lumby
# Processing Record 7 of Set 6 | manor
# Processing Record 8 of Set 6 | capesterre-belle-eau
# Processing Record 9 of Set 6 | sept-iles
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | frankfort
# Processing Record 12 of Set 6 | axim
# Processing Record 13 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 6 | altamont
# Processing Record 15 of Set 6 | catamarca
# Processing Record 16 of Set 6 | srednekolymsk
# Processing Record 17 of Set 6 | parambu
# Processing Record 18 of Set 6 | antalaha
# Processing Record 19 of Set 6 | oum hadjer
# Processing Record 20 of Set 6 | diamantino
# Processing Record 21 of Set 6 | hilo
# Processing Record 22 of Set 6 | omboue
# Processing Record 23 of Set 6 | praia da vitoria
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | labrea
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | sobolevo
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | nouakchott
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | morondava
# Processing Record 33 of Set 6 | port hedland
# Processing Record 34 of Set 6 | kuusamo
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | prince rupert
# Processing Record 37 of Set 6 | muncar
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | somanda
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | mormugao
# Processing Record 42 of Set 6 | minab
# Processing Record 43 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 6 | waddan
# Processing Record 45 of Set 6 | deer lake
# Processing Record 46 of Set 6 | solnechnyy
# Processing Record 47 of Set 6 | kpalime
# Processing Record 48 of Set 6 | dajal
# Processing Record 49 of Set 6 | merauke
# Processing Record 50 of Set 6 | disraeli
# Processing Record 1 of Set 7 | kupang
# Processing Record 2 of Set 7 | zlobin
# Processing Record 3 of Set 7 | nizhneangarsk
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | pacasmayo
# Processing Record 6 of Set 7 | huarmey
# Processing Record 7 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 7 | nioro
# Processing Record 9 of Set 7 | chuy
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | otane
# Processing Record 13 of Set 7 | kapit
# Processing Record 14 of Set 7 | kaduqli
# Processing Record 15 of Set 7 | guayaquil
# Processing Record 16 of Set 7 | playa vicente
# Processing Record 17 of Set 7 | nizhniy kuranakh
# Processing Record 18 of Set 7 | miandrivazo
# Processing Record 19 of Set 7 | san francisco
# Processing Record 20 of Set 7 | roebourne
# Processing Record 21 of Set 7 | burnie
# Processing Record 22 of Set 7 | sitka
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | labuhan
# Processing Record 25 of Set 7 | broome
# Processing Record 26 of Set 7 | abu samrah
# Processing Record 27 of Set 7 | ambovombe
# Processing Record 28 of Set 7 | skerries
# Processing Record 29 of Set 7 | tortoli
# Processing Record 30 of Set 7 | lagos
# Processing Record 31 of Set 7 | laguna de perlas
# Processing Record 32 of Set 7 | arraial do cabo
# Processing Record 33 of Set 7 | akyab
# Processing Record 34 of Set 7 | makat
# Processing Record 35 of Set 7 | arman
# Processing Record 36 of Set 7 | asau
# Processing Record 37 of Set 7 | mbuji-mayi
# Processing Record 38 of Set 7 | ciudad bolivar
# Processing Record 39 of Set 7 | tongzi
# Processing Record 40 of Set 7 | tongliao
# Processing Record 41 of Set 7 | waingapu
# Processing Record 42 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 7 | zaysan
# Processing Record 44 of Set 7 | whitehorse
# Processing Record 45 of Set 7 | cayenne
# Processing Record 46 of Set 7 | hun
# Processing Record 47 of Set 7 | bam
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | meadow lake
# Processing Record 50 of Set 7 | sakakah
# Processing Record 1 of Set 8 | mattru
# Processing Record 2 of Set 8 | bilma
# Processing Record 3 of Set 8 | dragutesti
# Processing Record 4 of Set 8 | biloela
# Processing Record 5 of Set 8 | kattivakkam
# Processing Record 6 of Set 8 | valparaiso
# Processing Record 7 of Set 8 | isla aguada
# Processing Record 8 of Set 8 | xai-xai
# Processing Record 9 of Set 8 | khani
# Processing Record 10 of Set 8 | roma
# Processing Record 11 of Set 8 | bambanglipuro
# Processing Record 12 of Set 8 | dobryanka
# Processing Record 13 of Set 8 | opuwo
# Processing Record 14 of Set 8 | usinsk
# Processing Record 15 of Set 8 | drayton valley
# Processing Record 16 of Set 8 | mizdah
# Processing Record 17 of Set 8 | morgan city
# Processing Record 18 of Set 8 | verkh-chebula
# Processing Record 19 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 8 | torbat-e jam
# Processing Record 21 of Set 8 | kasongo
# Processing Record 22 of Set 8 | havre-saint-pierre
# Processing Record 23 of Set 8 | victoria
# Processing Record 24 of Set 8 | gazli
# Processing Record 25 of Set 8 | sawtell
# Processing Record 26 of Set 8 | codrington
# Processing Record 27 of Set 8 | poquoson
# Processing Record 28 of Set 8 | necochea
# Processing Record 29 of Set 8 | chapleau
# Processing Record 30 of Set 8 | awbari
# Processing Record 31 of Set 8 | hamada
# Processing Record 32 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 8 | poya
# Processing Record 34 of Set 8 | yurya
# City not found. Skipping...
# Processing Record 35 of Set 8 | port hardy
# Processing Record 36 of Set 8 | aracruz
# Processing Record 37 of Set 8 | fairbanks
# Processing Record 38 of Set 8 | kawerau
# Processing Record 39 of Set 8 | barranco
# Processing Record 40 of Set 8 | siauliai
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | colatina
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | brae
# Processing Record 45 of Set 8 | killybegs
# Processing Record 46 of Set 8 | waipawa
# Processing Record 47 of Set 8 | alyangula
# Processing Record 48 of Set 8 | portel
# Processing Record 49 of Set 8 | xining
# Processing Record 50 of Set 8 | morehead
# Processing Record 1 of Set 9 | maloy
# Processing Record 2 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 9 | wagar
# Processing Record 4 of Set 9 | requena
# Processing Record 5 of Set 9 | puntarenas
# Processing Record 6 of Set 9 | santiago del estero
# Processing Record 7 of Set 9 | senanga
# Processing Record 8 of Set 9 | dunedin
# Processing Record 9 of Set 9 | joshimath
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | urfa
# City not found. Skipping...
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 9 | bagdarin
# Processing Record 15 of Set 9 | savinka
# Processing Record 16 of Set 9 | churapcha
# Processing Record 17 of Set 9 | oga
# Processing Record 18 of Set 9 | katsuura
# Processing Record 19 of Set 9 | sassandra
# Processing Record 20 of Set 9 | jaguaribe
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | saint-francois
# Processing Record 23 of Set 9 | lazaro cardenas
# Processing Record 24 of Set 9 | chapais
# Processing Record 25 of Set 9 | jining
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | kolokani
# Processing Record 28 of Set 9 | ust-kulom
# Processing Record 29 of Set 9 | balkhash
# Processing Record 30 of Set 9 | shache
# Processing Record 31 of Set 9 | enshi
# Processing Record 32 of Set 9 | trelew
# Processing Record 33 of Set 9 | cuiluan
# Processing Record 34 of Set 9 | adeje
# Processing Record 35 of Set 9 | wuda
# Processing Record 36 of Set 9 | lata
# Processing Record 37 of Set 9 | tombouctou
# Processing Record 38 of Set 9 | lokosovo
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | feijo
# Processing Record 41 of Set 9 | lambarene
# Processing Record 42 of Set 9 | pryozerne
# Processing Record 43 of Set 9 | kudahuvadhoo
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | halifax
# Processing Record 46 of Set 9 | sakyla
# Processing Record 47 of Set 9 | pacific grove
# Processing Record 48 of Set 9 | lompoc
# Processing Record 49 of Set 9 | haines junction
# Processing Record 50 of Set 9 | adrar
# Processing Record 1 of Set 10 | bay roberts
# Processing Record 2 of Set 10 | nacozari
# Processing Record 3 of Set 10 | bindi
# Processing Record 4 of Set 10 | ploemeur
# Processing Record 5 of Set 10 | margate
# Processing Record 6 of Set 10 | tiarei
# Processing Record 7 of Set 10 | aklavik
# Processing Record 8 of Set 10 | hokitika
# Processing Record 9 of Set 10 | muravlenko
# Processing Record 10 of Set 10 | mahibadhoo
# Processing Record 11 of Set 10 | paramirim
# Processing Record 12 of Set 10 | mogadishu
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | beira
# Processing Record 15 of Set 10 | zhigansk
# Processing Record 16 of Set 10 | port ellen
# City not found. Skipping...
# Processing Record 17 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 10 | kununurra
# Processing Record 19 of Set 10 | shushtar
# Processing Record 20 of Set 10 | batemans bay
# Processing Record 21 of Set 10 | kalamata
# Processing Record 22 of Set 10 | semaria
# Processing Record 23 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 10 | iquique
# Processing Record 25 of Set 10 | dauphin
# Processing Record 26 of Set 10 | teya
# Processing Record 27 of Set 10 | sungairaya
# Processing Record 28 of Set 10 | kaabong
# Processing Record 29 of Set 10 | muroto
# Processing Record 30 of Set 10 | el badari
# City not found. Skipping...
# Processing Record 31 of Set 10 | konstantinovka
# Processing Record 32 of Set 10 | salalah
# Processing Record 33 of Set 10 | plettenberg bay
# Processing Record 34 of Set 10 | buraydah
# Processing Record 35 of Set 10 | przasnysz
# Processing Record 36 of Set 10 | kollam
# Processing Record 37 of Set 10 | alta floresta
# Processing Record 38 of Set 10 | peleduy
# Processing Record 39 of Set 10 | giyani
# Processing Record 40 of Set 10 | anloga
# Processing Record 41 of Set 10 | santarem
# Processing Record 42 of Set 10 | araouane
# Processing Record 43 of Set 10 | nome
# Processing Record 44 of Set 10 | strezhevoy
# Processing Record 45 of Set 10 | kloulklubed
# Processing Record 46 of Set 10 | port moresby
# Processing Record 47 of Set 10 | kodinsk
# Processing Record 48 of Set 10 | bukama
# Processing Record 49 of Set 10 | yumen
# Processing Record 50 of Set 10 | matay
# Processing Record 1 of Set 11 | tabou
# Processing Record 2 of Set 11 | karratha
# Processing Record 3 of Set 11 | talpa
# Processing Record 4 of Set 11 | pagudpud
# Processing Record 5 of Set 11 | santa rosa
# Processing Record 6 of Set 11 | mae sai
# Processing Record 7 of Set 11 | saucillo
# Processing Record 8 of Set 11 | akdepe
# Processing Record 9 of Set 11 | uong bi
# Processing Record 10 of Set 11 | espanola
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | talara
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | iskateley
# Processing Record 15 of Set 11 | kasongo-lunda
# Processing Record 16 of Set 11 | kapustin yar
# Processing Record 17 of Set 11 | nortelandia
# Processing Record 18 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 11 | chuzhou
# Processing Record 20 of Set 11 | san andres
# Processing Record 21 of Set 11 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 22 of Set 11 | payo
# Processing Record 23 of Set 11 | taree
# Processing Record 24 of Set 11 | bonga
# Processing Record 25 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 11 | yatou
# Processing Record 27 of Set 11 | sosnovo-ozerskoye
# Processing Record 28 of Set 11 | baturaja
# Processing Record 29 of Set 11 | praya
# Processing Record 30 of Set 11 | tangi
# Processing Record 31 of Set 11 | maxixe
# Processing Record 32 of Set 11 | golden
# Processing Record 33 of Set 11 | huallanca
# Processing Record 34 of Set 11 | baherden
# Processing Record 35 of Set 11 | bolshoye pikino
# City not found. Skipping...
# Processing Record 36 of Set 11 | nanhai
# Processing Record 37 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 11 | nanakuli
# Processing Record 39 of Set 11 | cukai
# Processing Record 40 of Set 11 | abu dhabi
# Processing Record 41 of Set 11 | dingle
# Processing Record 42 of Set 11 | eydhafushi
# Processing Record 43 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 44 of Set 11 | torbay
# Processing Record 45 of Set 11 | melchor de mencos
# Processing Record 46 of Set 11 | ha noi
# Processing Record 47 of Set 11 | mirabad
# Processing Record 48 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | aranda de duero
# Processing Record 50 of Set 11 | nantucket
# Processing Record 1 of Set 12 | sistranda
# Processing Record 2 of Set 12 | mopti
# Processing Record 3 of Set 12 | narsaq
# Processing Record 4 of Set 12 | khomeynishahr
# City not found. Skipping...
# Processing Record 5 of Set 12 | mankono
# Processing Record 6 of Set 12 | nizhneivkino
# Processing Record 7 of Set 12 | cranbrook
# Processing Record 8 of Set 12 | rawson
# Processing Record 9 of Set 12 | beyneu
# Processing Record 10 of Set 12 | kulhudhuffushi
# Processing Record 11 of Set 12 | khandbari
# Processing Record 12 of Set 12 | road town
# Processing Record 13 of Set 12 | agadez
# Processing Record 14 of Set 12 | san
# Processing Record 15 of Set 12 | ballina
# Processing Record 16 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 17 of Set 12 | itoman
# Processing Record 18 of Set 12 | westport
# Processing Record 19 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 12 | caravelas
# Processing Record 21 of Set 12 | bathsheba
# Processing Record 22 of Set 12 | juba
# Processing Record 23 of Set 12 | carauari
# Processing Record 24 of Set 12 | bandarbeyla
# Processing Record 25 of Set 12 | andenes
# Processing Record 26 of Set 12 | xingtai
# Processing Record 27 of Set 12 | souillac
# Processing Record 28 of Set 12 | mayskiy
# Processing Record 29 of Set 12 | yarmouth
# Processing Record 30 of Set 12 | hervey bay
# Processing Record 31 of Set 12 | gushikawa
# Processing Record 32 of Set 12 | augusto correa
# Processing Record 33 of Set 12 | aden
# Processing Record 34 of Set 12 | tamiahua
# Processing Record 35 of Set 12 | brawley
# Processing Record 36 of Set 12 | phulabani
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | tadine
# Processing Record 39 of Set 12 | fatehabad
# Processing Record 40 of Set 12 | mikkeli
# Processing Record 41 of Set 12 | havoysund
# Processing Record 42 of Set 12 | hualmay
# Processing Record 43 of Set 12 | cloquet
# Processing Record 44 of Set 12 | bilibino
# Processing Record 45 of Set 12 | mizan teferi
# Processing Record 46 of Set 12 | shieli
# Processing Record 47 of Set 12 | dicabisagan
# Processing Record 48 of Set 12 | komsomolskiy
# Processing Record 49 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 50 of Set 12 | weinan
# Processing Record 1 of Set 13 | soc trang
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | coquimbo
# Processing Record 4 of Set 13 | panguna
# Processing Record 5 of Set 13 | abha
# Processing Record 6 of Set 13 | faya
# Processing Record 7 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 13 | nouadhibou
# Processing Record 9 of Set 13 | kawalu
# Processing Record 10 of Set 13 | arica
# Processing Record 11 of Set 13 | shasta lake
# Processing Record 12 of Set 13 | arroio dos ratos
# Processing Record 13 of Set 13 | harper
# Processing Record 14 of Set 13 | makakilo city
# Processing Record 15 of Set 13 | fort-shevchenko
# Processing Record 16 of Set 13 | sabang
# Processing Record 17 of Set 13 | chauk
# Processing Record 18 of Set 13 | los llanos de aridane
# Processing Record 19 of Set 13 | aripuana
# Processing Record 20 of Set 13 | pangkalanbuun
# Processing Record 21 of Set 13 | nizwa
# Processing Record 22 of Set 13 | sawakin
# Processing Record 23 of Set 13 | udachnyy
# Processing Record 24 of Set 13 | la rioja
# Processing Record 25 of Set 13 | zafra
# Processing Record 26 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 27 of Set 13 | marrakesh
# Processing Record 28 of Set 13 | linfen
# Processing Record 29 of Set 13 | betare oya
# Processing Record 30 of Set 13 | troitsko-pechorsk
# Processing Record 31 of Set 13 | brigantine
# Processing Record 32 of Set 13 | panshi
# Processing Record 33 of Set 13 | blythe
# Processing Record 34 of Set 13 | ha tinh
# Processing Record 35 of Set 13 | maltahohe
# Processing Record 36 of Set 13 | zarubino
# Processing Record 37 of Set 13 | poretskoye
# Processing Record 38 of Set 13 | lithakia
# Processing Record 39 of Set 13 | maragogi
# Processing Record 40 of Set 13 | vryheid
# Processing Record 41 of Set 13 | ternate
# Processing Record 42 of Set 13 | moa
# Processing Record 43 of Set 13 | yola
# Processing Record 44 of Set 13 | leona vicario
# Processing Record 45 of Set 13 | reigate
# Processing Record 46 of Set 13 | pyapon
# Processing Record 47 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 48 of Set 13 | batagay-alyta
# Processing Record 49 of Set 13 | bikin
# Processing Record 50 of Set 13 | san antonio
# Processing Record 1 of Set 14 | myrtle beach
# Processing Record 2 of Set 14 | bati
# Processing Record 3 of Set 14 | riyadh
# Processing Record 4 of Set 14 | muisne
# Processing Record 5 of Set 14 | grants pass
# Processing Record 6 of Set 14 | tual
# Processing Record 7 of Set 14 | simbahan
# Processing Record 8 of Set 14 | conceicao do araguaia
# Processing Record 9 of Set 14 | ukiah
# Processing Record 10 of Set 14 | dano
# Processing Record 11 of Set 14 | naryan-mar
# Processing Record 12 of Set 14 | owando
# Processing Record 13 of Set 14 | lesozavodsk
# Processing Record 14 of Set 14 | noshiro
# Processing Record 15 of Set 14 | ust-nera
# Processing Record 16 of Set 14 | moroni
# Processing Record 17 of Set 14 | abu zabad
# Processing Record 18 of Set 14 | mabaruma
# Processing Record 19 of Set 14 | flinders
# Processing Record 20 of Set 14 | bayan
# Processing Record 21 of Set 14 | luwuk
# Processing Record 22 of Set 14 | bridlington
# Processing Record 23 of Set 14 | lamani
# Processing Record 24 of Set 14 | rabo de peixe
# Processing Record 25 of Set 14 | guiratinga
# Processing Record 26 of Set 14 | colonial heights
# Processing Record 27 of Set 14 | makaha
# Processing Record 28 of Set 14 | ginir
# Processing Record 29 of Set 14 | kapoeta
# Processing Record 30 of Set 14 | gwanda
# Processing Record 31 of Set 14 | ati
# Processing Record 32 of Set 14 | nabire
# Processing Record 33 of Set 14 | la palma
# Processing Record 34 of Set 14 | tura
# Processing Record 35 of Set 14 | tanza
# Processing Record 36 of Set 14 | bad segeberg
# Processing Record 37 of Set 14 | san jose de guanipa
# Processing Record 38 of Set 14 | shunyi
# Processing Record 39 of Set 14 | rorvik
# Processing Record 40 of Set 14 | ucluelet
# Processing Record 41 of Set 14 | kuching
# Processing Record 42 of Set 14 | rewa
# Processing Record 43 of Set 14 | mana
# Processing Record 44 of Set 14 | kornye
# Processing Record 45 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 14 | macusani
# Processing Record 47 of Set 14 | mwingi
# Processing Record 48 of Set 14 | sidi qasim
# City not found. Skipping...
# Processing Record 49 of Set 14 | luanda
# Processing Record 50 of Set 14 | zhanakorgan
# Processing Record 1 of Set 15 | shurugwi
# Processing Record 2 of Set 15 | mecca
# Processing Record 3 of Set 15 | dalbandin
# Processing Record 4 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | bahir dar
# Processing Record 7 of Set 15 | lesosibirsk
# Processing Record 8 of Set 15 | ye
# City not found. Skipping...
# Processing Record 9 of Set 15 | carballo
# Processing Record 10 of Set 15 | peniche
# Processing Record 11 of Set 15 | oildale
# Processing Record 12 of Set 15 | alice springs
# Processing Record 13 of Set 15 | shimoda
# Processing Record 14 of Set 15 | skelleftea
# Processing Record 15 of Set 15 | antsla
# Processing Record 16 of Set 15 | penha
# Processing Record 17 of Set 15 | san policarpo
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | trang
# Processing Record 20 of Set 15 | fortuna
# Processing Record 21 of Set 15 | savelugu
# Processing Record 22 of Set 15 | summerville
# Processing Record 23 of Set 15 | binga
# Processing Record 24 of Set 15 | saint-leu
# Processing Record 25 of Set 15 | yarada
# Processing Record 26 of Set 15 | kyshtovka
# Processing Record 27 of Set 15 | durban
# Processing Record 28 of Set 15 | arlit
# Processing Record 29 of Set 15 | valea larga
# City not found. Skipping...
# Processing Record 30 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 15 | general pico
# Processing Record 32 of Set 15 | sungaipenuh
# Processing Record 33 of Set 15 | rudkobing
# Processing Record 34 of Set 15 | ongandjera
# Processing Record 35 of Set 15 | sao miguel do araguaia
# Processing Record 36 of Set 15 | saint-georges
# Processing Record 37 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 38 of Set 15 | tocopilla
# Processing Record 39 of Set 15 | najran
# Processing Record 40 of Set 15 | sterling
# Processing Record 41 of Set 15 | bairiki
# Processing Record 42 of Set 15 | malkangiri
# Processing Record 43 of Set 15 | chavakkad
# Processing Record 44 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 45 of Set 15 | masuguru
# Processing Record 46 of Set 15 | kushmurun
# Processing Record 47 of Set 15 | busayra
# Processing Record 48 of Set 15 | atambua
# Processing Record 49 of Set 15 | chikwawa
# Processing Record 50 of Set 15 | ust-kuyga
# Processing Record 1 of Set 16 | olafsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Dongsheng  39.8161  109.9776     68.61        17          33
# 1          Alpena  45.0617  -83.4327     53.94        46           1
# 2    Puerto Ayora  -0.7393  -90.3518     75.54        89          76
# 3          Hobart -42.8794  147.3294     42.66        81          75
# 4  Virginia Beach  36.8529  -75.9780     93.27        48          40
#
#    Wind Speed Country Current Description
# 0       19.93      CN    scattered clouds
# 1        1.99      US           clear sky
# 2        5.99      EC       broken clouds
# 3        1.01      AU       broken clouds
# 4       13.80      US    scattered clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Current Description"]
city_data_new_df = city_data_df[new_column_order]
city_data_new_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Dongsheng      CN  39.8161  109.9776     68.61        17          33
# 1          Alpena      US  45.0617  -83.4327     53.94        46           1
# 2    Puerto Ayora      EC  -0.7393  -90.3518     75.54        89          76
# 3          Hobart      AU -42.8794  147.3294     42.66        81          75
# 4  Virginia Beach      US  36.8529  -75.9780     93.27        48          40
#
#   Current Description
# 0    scattered clouds
# 1           clear sky
# 2       broken clouds
# 3       broken clouds
# 4    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
